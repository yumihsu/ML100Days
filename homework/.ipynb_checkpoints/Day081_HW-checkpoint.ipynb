# %% [markdown]
# ## Work
# 1. 請比較使用 l1, l1_l2 及不同比例下的訓練結果

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "TCC/WDDM"

# %%
from keras.regularizers import l1,l1_l2,l2

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
def build_mlp(input_shape, output_unit = 10 , num_nerous = [512,256,128,64],l2_ratio=1e-4):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    for i , num in enumerate(num_nerous):
        if i == 0:
            x = keras.layers.Dense(units= num,
                                  activation = 'relu',
                                  name = 'hidden_layers'+ str(i+1),
                                  kernel_regularizer = l2(l2_ratio))(input_layer)
        else :
            x = keras.layers.Dense(units = num ,
                                  activation = 'relu',
                                  name = 'hidden_layers'+ str(i+1),
                                  kernel_regularizer = l2(l2_ratio))(x)
    output = keras.layers.Dense(units  = output_unit,
                               activation = 'softmax',
                               name = 'output_layers')(x)
    model = keras.models.Model(inputs = [input_layer],
                              outputs = [output])
    return model

# %%
"""Code Here
設定超參數
"""
learning_rate = 0.001
EPOCH = 20
BATCH_SIZE = 256
MOMENTUM = 0.95
L2_EXP = [1e-2, 1e-4, 1e-8, 1e-12]

model = build_mlp(input_shape= x_train.shape[1:])
optimizers_1 = keras.optimizers.Adam(lr = learning_rate)
model.compile( loss ='categorical_crossentropy',
             metrics = 'acc',
             optimizer = optimizers_1)

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
for regulizer_ratio in L2_EXP:
    keras.backend.clear_session() # 把舊的 Graph 清掉
    print("Experiment with Regulizer = %.6f" % (regulizer_ratio))
    model = build_mlp(input_shape=x_train.shape[1:], l2_ratio=regulizer_ratio)
    model.summary()
    optimizer = keras.optimizers.SGD(lr=learning_rate, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCH, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    exp_name_tag = "exp-l2-%s" % str(regulizer_ratio)
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# Experiment with Regulizer = 0.010000
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layers1 (Dense)       (None, 512)               1573376
# _________________________________________________________________
# hidden_layers2 (Dense)       (None, 256)               131328
# _________________________________________________________________
# hidden_layers3 (Dense)       (None, 128)               32896
# _________________________________________________________________
# hidden_layers4 (Dense)       (None, 64)                8256
# _________________________________________________________________
# output_layers (Dense)        (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 196/196 [==============================] - 3s 13ms/step - loss: 15.8775 - accuracy: 0.2562 - val_loss: 14.7023 - val_accuracy: 0.3105
# Epoch 2/20
# 196/196 [==============================] - 2s 12ms/step - loss: 13.7008 - accuracy: 0.3445 - val_loss: 12.7592 - val_accuracy: 0.3553
# Epoch 3/20
# 196/196 [==============================] - 2s 13ms/step - loss: 11.9350 - accuracy: 0.3700 - val_loss: 11.1452 - val_accuracy: 0.3796
# Epoch 4/20
# 196/196 [==============================] - 2s 12ms/step - loss: 10.4464 - accuracy: 0.3854 - val_loss: 9.7777 - val_accuracy: 0.3893
# Epoch 5/20
# 196/196 [==============================] - 3s 13ms/step - loss: 9.1823 - accuracy: 0.3940 - val_loss: 8.6082 - val_accuracy: 0.4008
# Epoch 6/20
# 196/196 [==============================] - 3s 13ms/step - loss: 8.1033 - accuracy: 0.4023 - val_loss: 7.6174 - val_accuracy: 0.4062
# Epoch 7/20
# Epoch 5/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.7631 - accuracy: 0.4279 - val_loss: 1.7354 - val_accuracy: 0.4424
# Epoch 6/20
# 196/196 [==============================] - 2s 13ms/step - loss: 1.7183 - accuracy: 0.4455 - val_loss: 1.7104 - val_accuracy: 0.4475
# Epoch 7/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.6789 - accuracy: 0.4597 - val_loss: 1.6943 - val_accuracy: 0.4517
# Epoch 8/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.6428 - accuracy: 0.4721 - val_loss: 1.6839 - val_accuracy: 0.4592
# Epoch 9/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.6133 - accuracy: 0.4824 - val_loss: 1.7006 - val_accuracy: 0.4487
# Epoch 10/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.5826 - accuracy: 0.4919 - val_loss: 1.6099 - val_accuracy: 0.4809
# Epoch 11/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.5558 - accuracy: 0.5030 - val_loss: 1.5923 - val_accuracy: 0.4911
# Epoch 12/20
# 196/196 [==============================] - 2s 13ms/step - loss: 1.5316 - accuracy: 0.5106 - val_loss: 1.5847 - val_accuracy: 0.4877
# Epoch 13/20
# 196/196 [==============================] - 2s 13ms/step - loss: 1.5070 - accuracy: 0.5203 - val_loss: 1.5701 - val_accuracy: 0.4964
# Epoch 14/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.4863 - accuracy: 0.5262 - val_loss: 1.5785 - val_accuracy: 0.4914
# Epoch 15/20
# 196/196 [==============================] - 2s 13ms/step - loss: 1.4654 - accuracy: 0.5346 - val_loss: 1.5482 - val_accuracy: 0.5023
# Epoch 16/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.4468 - accuracy: 0.5420 - val_loss: 1.5340 - val_accuracy: 0.5016
# Epoch 17/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.4270 - accuracy: 0.5468 - val_loss: 1.5284 - val_accuracy: 0.5050
# Epoch 18/20
# 196/196 [==============================] - 2s 13ms/step - loss: 1.4089 - accuracy: 0.5554 - val_loss: 1.5014 - val_accuracy: 0.5168
# Epoch 19/20
# 196/196 [==============================] - 3s 13ms/step - loss: 1.3891 - accuracy: 0.5614 - val_loss: 1.5362 - val_accuracy: 0.5034
# Epoch 20/20
# 196/196 [==============================] - 3s 13ms/step - loss: 1.3730 - accuracy: 0.5650 - val_loss: 1.5238 - val_accuracy: 0.5137
# Experiment with Regulizer = 0.000000
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layers1 (Dense)       (None, 512)               1573376
# _________________________________________________________________
# hidden_layers2 (Dense)       (None, 256)               131328
# _________________________________________________________________
# hidden_layers3 (Dense)       (None, 128)               32896
# _________________________________________________________________
# hidden_layers4 (Dense)       (None, 64)                8256
# _________________________________________________________________
# output_layers (Dense)        (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 196/196 [==============================] - 3s 13ms/step - loss: 2.0761 - accuracy: 0.2578 - val_loss: 1.9059 - val_accuracy: 0.3208
# Epoch 2/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.8399 - accuracy: 0.3478 - val_loss: 1.7836 - val_accuracy: 0.3730
# Epoch 3/20
# 196/196 [==============================] - 2s 13ms/step - loss: 1.7434 - accuracy: 0.3837 - val_loss: 1.7136 - val_accuracy: 0.4001
# Epoch 4/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.6781 - accuracy: 0.4062 - val_loss: 1.6626 - val_accuracy: 0.4105
# Epoch 5/20
# 196/196 [==============================] - 3s 13ms/step - loss: 1.6272 - accuracy: 0.4255 - val_loss: 1.6154 - val_accuracy: 0.4266
# Epoch 6/20
# 196/196 [==============================] - 2s 13ms/step - loss: 1.5840 - accuracy: 0.4404 - val_loss: 1.5666 - val_accuracy: 0.4462
# Epoch 7/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.5444 - accuracy: 0.4537 - val_loss: 1.5404 - val_accuracy: 0.4508
# Epoch 8/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.5074 - accuracy: 0.4677 - val_loss: 1.5205 - val_accuracy: 0.4548
# Epoch 9/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.4778 - accuracy: 0.4772 - val_loss: 1.5165 - val_accuracy: 0.4585
# Epoch 10/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.4482 - accuracy: 0.4873 - val_loss: 1.4927 - val_accuracy: 0.4722
# Epoch 11/20
# 196/196 [==============================] - 3s 13ms/step - loss: 1.4228 - accuracy: 0.4960 - val_loss: 1.4679 - val_accuracy: 0.4778
# Epoch 12/20
# 196/196 [==============================] - 3s 13ms/step - loss: 1.3965 - accuracy: 0.5055 - val_loss: 1.4524 - val_accuracy: 0.4836
# Epoch 13/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.3774 - accuracy: 0.5126 - val_loss: 1.4223 - val_accuracy: 0.4935
# Epoch 14/20
# 196/196 [==============================] - 2s 13ms/step - loss: 1.3513 - accuracy: 0.5232 - val_loss: 1.4622 - val_accuracy: 0.4808
# Epoch 15/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.3333 - accuracy: 0.5265 - val_loss: 1.4418 - val_accuracy: 0.4858
# Epoch 16/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.3155 - accuracy: 0.5333 - val_loss: 1.4478 - val_accuracy: 0.4879
# Epoch 17/20
# 196/196 [==============================] - 2s 13ms/step - loss: 1.3003 - accuracy: 0.5405 - val_loss: 1.4029 - val_accuracy: 0.4990
# Epoch 18/20
# 196/196 [==============================] - 2s 13ms/step - loss: 1.2778 - accuracy: 0.5468 - val_loss: 1.4257 - val_accuracy: 0.4926
# Epoch 19/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.2622 - accuracy: 0.5508 - val_loss: 1.3918 - val_accuracy: 0.5030
# Epoch 20/20
# 196/196 [==============================] - 2s 12ms/step - loss: 1.2450 - accuracy: 0.5586 - val_loss: 1.4299 - val_accuracy: 0.4932
# Experiment with Regulizer = 0.000000
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layers1 (Dense)       (None, 512)               1573376
# _________________________________________________________________
# hidden_layers2 (Dense)       (None, 256)               131328
# _________________________________________________________________
# hidden_layers3 (Dense)       (None, 128)               32896
# _________________________________________________________________
# hidden_layers4 (Dense)       (None, 64)                8256
# _________________________________________________________________
# output_layers (Dense)        (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1